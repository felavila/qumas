# %%
import pandas as pd
import matplotlib.pyplot as plt
#import time_scales_estimation_code
from qumas.Tools.postanalysis_utils import log10_to_number,r_x_to_r_y,cm_to_lday,lday_to_cm,to_return,montecarlo_errors
from qumas.Tools.linear_fit_tools import make_linear_fit,evaluate_with_uncertainties,linear_func
import scipy.odr as odr
import numpy as np
import os

# %%
our_results_v2 = pd.read_csv("../Tables/best_models_results_new_rescale.csv", index_col = False, skipinitialspace=True)

# %%
print("ts",montecarlo_errors(our_results_v2['ts_rescaled_8140/(1+zs)'].values,our_results_v2['e_ts_rescaled_8140/(1+zs)'].values,N=100))
# Out:
# Median = 2.588 $\pm$ 0.066
# ts (np.float64(2.5880414825405573), np.float64(0.06585642465285303))
