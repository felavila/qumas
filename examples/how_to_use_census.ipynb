# %% [markdown]
# # **Notebook**: How to use the census.

# %%
from qumas.census import LensedQsoCensus

# %%
LQC=LensedQsoCensus()

# %%
LQC.hierarchical_selection("GRAL1651-0417")
# Out:
#                       name    z_l    z_s        ra     dec component    IS  \
# 188          GRAL1651-0417  0.591  1.451  252.7724 -4.2903       NaN   NaN
# 1104  GraLJ165105.3-041725  0.591  1.451  252.7724 -4.2903         A   ima
# 1105  GraLJ165105.3-041725  0.591  1.451  252.7724 -4.2903         B   ima
# 1106  GraLJ165105.3-041725  0.591  1.451  252.7724 -4.2903         C   ima
# 1107  GraLJ165105.3-041725  0.591  1.451  252.7724 -4.2903         D   ima
# 1108  GraLJ165105.3-041725  0.591  1.451  252.7724 -4.2903         G  lens
#
#           RA    dRA      DEC  ...              Bibcode  \
# 188      NaN    NaN      NaN  ...  2021ApJ...921...42S
# 1104  0.0000  0.002      0.0  ...  2021ApJ...921...42S
# 1105 -3.2119  0.002  -5.7522  ...  2021ApJ...921...42S
# 1106 -7.8631  0.002  -6.3014  ...  2021ApJ...921...42S
# 1107 -6.3679  0.002  -1.6598  ...  2021ApJ...921...42S
# 1108 -4.5961  0.010  -3.1504  ...  2021ApJ...921...42S
#
# ...
